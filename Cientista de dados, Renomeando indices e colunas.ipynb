# %% [markdown]
# # Índice <a name="Contents"></a>
# 1. [Importando bibliotecas](#import)
# 2. [Construindo um dataframe](#read)
# 3. [Renomeando colunas](#colunas)
# 4. [Renomeando índices](#indices)

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import pandas as pd
import numpy  as np

# %% [markdown]
# # 2. Construindo um dataframe <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
df = pd.DataFrame(
    np.random.randn(9, 4)*100,
    index=["A", "B", "C", "D", "E", "F", "G", "H", "I"],
    columns=["coluna1", "coluna2", "coluna3","coluna4"],
)
df
# Out:
#       coluna1    coluna2     coluna3     coluna4
# A  254.770715 -33.314128   41.892405 -112.335602
# B  -28.975917 -26.933098  135.995404  -54.506801
# C  -33.163982 -68.807123   39.110437 -216.983804
# D   21.481124  -1.072524   15.134578  107.455258
# E  -92.361583 -42.569261   25.737415  -35.391335
# F   12.325290 -11.399921  -71.442879   65.251164
# G  -87.984688  96.599539 -229.424657  -79.371223
# H   72.013105  57.497357  131.345693   88.799711
# I   17.983638 -38.621897  -34.866863  112.478261

# %% [markdown]
# # 3. Renomeando colunas <a name="colunas"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
df.columns
# Out:
# Index(['coluna1', 'coluna2', 'coluna3', 'coluna4'], dtype='object')

# %%
df.columns = ['segunda', 'terça', 'quarta', 'quinta']

# %%
df.columns
# Out:
# Index(['segunda', 'terça', 'quarta', 'quinta'], dtype='object')

# %%
df
# Out:
#       segunda      terça      quarta      quinta
# A  254.770715 -33.314128   41.892405 -112.335602
# B  -28.975917 -26.933098  135.995404  -54.506801
# C  -33.163982 -68.807123   39.110437 -216.983804
# D   21.481124  -1.072524   15.134578  107.455258
# E  -92.361583 -42.569261   25.737415  -35.391335
# F   12.325290 -11.399921  -71.442879   65.251164
# G  -87.984688  96.599539 -229.424657  -79.371223
# H   72.013105  57.497357  131.345693   88.799711
# I   17.983638 -38.621897  -34.866863  112.478261

# %% [markdown]
# # 4. Renomeando índices <a name="indices"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
df['coluna5'] = ['letraA','letraB','letraC','letraD','letraE','letraF','letraG','letraH','letraI']

# %%
df
# Out:
#       segunda      terça      quarta      quinta coluna5
# A  254.770715 -33.314128   41.892405 -112.335602  letraA
# B  -28.975917 -26.933098  135.995404  -54.506801  letraB
# C  -33.163982 -68.807123   39.110437 -216.983804  letraC
# D   21.481124  -1.072524   15.134578  107.455258  letraD
# E  -92.361583 -42.569261   25.737415  -35.391335  letraE
# F   12.325290 -11.399921  -71.442879   65.251164  letraF
# G  -87.984688  96.599539 -229.424657  -79.371223  letraG
